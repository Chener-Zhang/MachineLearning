# %%
import pandas as pd 
import numpy as np
from urllib.parse import urlparse

# %%
df = pd.read_csv("3-21-2022.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1720 entries, 0 to 1719
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order       1720 non-null   int64
#  1   id          1720 non-null   int64
#  2   date        1720 non-null   object
#  3   time        1720 non-null   object
#  4   title       1720 non-null   object
#  5   url         1720 non-null   object
#  6   visitCount  1720 non-null   int64
#  7   typedCount  1720 non-null   int64
#  8   transition  1720 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 121.1+ KB

# %%
df.head()
# Out:
#    order     id       date      time  \
# 0      0  22243  3/21/2022  17:13:30
# 1      1  22242  3/21/2022  17:13:24
# 2      2  22241  3/21/2022  17:13:23
# 3      3  22241  3/21/2022  17:13:22
# 4      4     22  3/21/2022  17:13:15
#
#                                       title  \
# 0  Export Chrome History - Chrome Web Store
# 1  Export Chrome History - Chrome Web Store
# 2     export google history - Google Search
# 3     export google history - Google Search
# 4                                   YouTube
#
#                                                  url  visitCount  typedCount  \
# 0  https://chrome.google.com/webstore/detail/expo...           1           0
# 1  https://chrome.google.com/webstore/detail/expo...           1           0
# 2  https://www.google.com/search?q=export+google+...           2           0
# 3  https://www.google.com/search?q=export+google+...           2           0
# 4                           https://www.youtube.com/        2217           1
#
#       transition
# 0           link
# 1           link
# 2           link
# 3      generated
# 4  auto_bookmark

# %%
df['time'] = pd.to_datetime(df['time'],format= '%H:%M:%S' ).dt.time

# %%
df['url'] = df['url'].astype('string')

# %%
# df.info()

# %%
df['url'] = df['url'].apply(lambda x:urlparse(x).netloc)

# %%
df
# Out:
#       order     id       date      time  \
# 0         0  22243  3/21/2022  17:13:30
# 1         1  22242  3/21/2022  17:13:24
# 2         2  22241  3/21/2022  17:13:23
# 3         3  22241  3/21/2022  17:13:22
# 4         4     22  3/21/2022  17:13:15
# ...     ...    ...        ...       ...
# 1715   1715  21752  3/20/2022  17:25:09
# 1716   1716  21752  3/20/2022  17:25:08
# 1717   1717  21751  3/20/2022  17:24:34
# 1718   1718  21750  3/20/2022  17:24:31
# 1719   1719  21750  3/20/2022  17:24:31
#
#                                          title                url  visitCount  \
# 0     Export Chrome History - Chrome Web Store  chrome.google.com           1
# 1     Export Chrome History - Chrome Web Store  chrome.google.com           1
# 2        export google history - Google Search     www.google.com           2
# 3        export google history - Google Search     www.google.com           2
# 4                                      YouTube    www.youtube.com        2217
# ...                                        ...                ...         ...
# 1715                      八字排盘 - Google Search     www.google.com           3
# 1716                      八字排盘 - Google Search     www.google.com           3
# 1717                                   八字六亲与宫位     www.360doc.com           1
# 1718                   八字 父亲宫位 - Google Search     www.google.com           2
# 1719                   八字 父亲宫位 - Google Search     www.google.com           2
#
#       typedCount     transition
# 0              0           link
# 1              0           link
# 2              0           link
# 3              0      generated
# 4              1  auto_bookmark
# ...          ...            ...
# 1715           0           link
# 1716           0      generated
# 1717           0           link
# 1718           0           link
# 1719           0      generated
#
# [1720 rows x 9 columns]
